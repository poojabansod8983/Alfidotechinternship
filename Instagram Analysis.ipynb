# %%
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_comments = pd.read_csv("C:\\Users\\pooja\\Instagram prediction\\comments.csv")
df_comments
# Out:
#         id                 comment  User  id  Photo id created Timestamp  \
# 0        1         unde at dolorem         2         1  13-04-2023 08:04
# 1        2         quae ea ducimus         3         1  13-04-2023 08:04
# 2        3      alias a voluptatum         5         1  13-04-2023 08:04
# 3        4    facere suscipit sunt        14         1  13-04-2023 08:04
# 4        5  totam eligendi quaerat        17         1  13-04-2023 08:04
# ...    ...                     ...       ...       ...               ...
# 7483  7484       accusamus vel est        82       257  13-04-2023 08:04
# 7484  7485           sit nulla qui        91       257  13-04-2023 08:04
# 7485  7486        sed quidem vitae        93       257  13-04-2023 08:04
# 7486  7487   dolorem eveniet rerum        95       257  13-04-2023 08:04
# 7487  7488  dolores nihil voluptas        96       257  13-04-2023 08:04
#
#      posted date emoji used  Hashtags used count
# ...

# %%
df_comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7488 entries, 0 to 7487
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   7488 non-null   int64
#  1   comment              7488 non-null   object
#  2   User  id             7488 non-null   int64
#  3   Photo id             7488 non-null   int64
#  4   created Timestamp    7488 non-null   object
#  5   posted date          7488 non-null   object
#  6   emoji used           7488 non-null   object
#  7   Hashtags used count  7488 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 468.1+ KB

# %%
df_comments.isnull()
# Out:
#          id  comment  User  id  Photo id  created Timestamp  posted date  \
# 0     False    False     False     False              False        False
# 1     False    False     False     False              False        False
# 2     False    False     False     False              False        False
# 3     False    False     False     False              False        False
# 4     False    False     False     False              False        False
# ...     ...      ...       ...       ...                ...          ...
# 7483  False    False     False     False              False        False
# 7484  False    False     False     False              False        False
# 7485  False    False     False     False              False        False
# 7486  False    False     False     False              False        False
# 7487  False    False     False     False              False        False
#
#       emoji used  Hashtags used count
# 0          False                False
# ...

# %%
df_comments.shape
# Out:
# (7488, 8)

# %%
df_comments.isnull().sum()
# Out:
# id                     0
# comment                0
# User  id               0
# Photo id               0
# created Timestamp      0
# posted date            0
# emoji used             0
# Hashtags used count    0
# dtype: int64

# %%
df_comments["emoji used"].value_counts()
# Out:
# yes    3744
# no     3744
# Name: emoji used, dtype: int64

# %%
import matplotlib.pyplot as plt

df_comments['Hashtags used count'].value_counts().plot(kind="pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Phototags

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\pooja\\Instagram prediction\\photo_tags.csv")

# %%
df.head()
# Out:
#    photo  tag ID  user id
# 0      1      13        1
# 1      1      17        1
# 2      1      18        2
# 3      1      19        2
# 4      1      21        3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   photo    501 non-null    int64
#  1   tag ID   501 non-null    int64
#  2   user id  501 non-null    int64
# dtypes: int64(3)
# memory usage: 11.9 KB

# %% [markdown]
# follows

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\pooja\\Instagram prediction\\follows.csv")

# %%
df.head()
# Out:
#    follower  followee       created time  is follower active  \
# 0         2          1  13-04-2023 08:04                   1
# 1         2          3  13-04-2023 08:04                   0
# 2         2          4  13-04-2023 08:04                   0
# 3         2          5  13-04-2023 08:04                   0
# 4         2          6  13-04-2023 08:04                   1
#
#   followee Acc status
# 0             Private
# 1             private
# 2              public
# 3             private
# 4             private

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7623 entries, 0 to 7622
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   follower             7623 non-null   int64
#  1   followee             7623 non-null   int64
#  2   created time         7623 non-null   object
#  3   is follower active   7623 non-null   int64
#  4   followee Acc status  7623 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 297.9+ KB

# %%
df.isnull()
# Out:
#       follower  followee   created time  is follower active  \
# 0        False      False         False               False
# 1        False      False         False               False
# 2        False      False         False               False
# 3        False      False         False               False
# 4        False      False         False               False
# ...        ...        ...           ...                 ...
# 7618     False      False         False               False
# 7619     False      False         False               False
# 7620     False      False         False               False
# 7621     False      False         False               False
# 7622     False      False         False               False
#
#       followee Acc status
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 7618                False
# ...

# %%
def preprocess_text(text):
    text = str(text).lower()  # Convert to lowercase
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    tokens = word_tokenize(text)  # Tokenize text
    # Remove stopwords
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return " ".join(tokens)

# %%
df["follower"].value_counts()
# Out:
# 2      99
# 62     99
# 71     99
# 70     99
# 69     99
#        ..
# 31     99
# 30     99
# 28     99
# 27     99
# 100    99
# Name: follower, Length: 77, dtype: int64

# %%
import matplotlib.pyplot as plt

df['follower'].value_counts().plot(kind="pie", autopct='%3.1f%%')
plt.show()

# %%
# Data Visualization
plt.figure(figsize=(10, 6))
sns.countplot(x=df['follower'], palette='coolwarm')
plt.title("Instagram followers")
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_1908\664993589.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")

# %% [markdown]
# tags

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\pooja\\Instagram prediction\\tags.csv")

# %%
df.head()
# Out:
#    id     tag text      created time       location
# 0   1       sunset  13-04-2023 08:04        florida
# 1   2  photography  13-04-2023 08:04  washington DC
# 2   3      sunrise  13-04-2023 08:04       new york
# 3   4    landscape  13-04-2023 08:04         london
# 4   5         food  13-04-2023 08:04         brazil

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            21 non-null     int64
#  1   tag text      21 non-null     object
#  2   created time  21 non-null     object
#  3   location      21 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 800.0+ bytes

# %%
df.isnull().sum()
# Out:
# id              0
# tag text        0
# created time    0
# location        0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df['created time'].value_counts().plot(kind="pie", autopct='%1.1f%%')
plt.show()

# %%
labels = ['Category A', 'Category B', 'Category C']
sizes = [15, 30, 45,]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0.1, 0, 0)  # Only "explode" the 2nd slice

plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Tags Pie Chart")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 6
#       3 colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
#       4 explode = (0, 0.1, 0, 0)  # Only "explode" the 2nd slice
# ----> 6 plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)
#       7 plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#       8 plt.title("Tags Pie Chart")
#
# File D:\Anaconda\lib\site-packages\matplotlib\pyplot.py:2772, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2765 @_copy_docstring_and_deprecators(Axes.pie)
#    2766 def pie(
#    2767         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['tag text'], df['created time'], color='skyblue')
plt.xlabel('tag text')
plt.ylabel('created time')
plt.title('Bar Chart from CSV Data')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
